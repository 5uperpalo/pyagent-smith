# %% [markdown]
# # <a id='toc1_'></a>[Description](#toc0_)

# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# - [Description](#toc1_)
# - [Imports](#toc2_)
# - [Examples](#toc3_)
#   - [Simple](#toc3_1_)
#   - [With conversation history](#toc3_2_)
#   - [With direct agent executor for more control](#toc3_3_)
#   - [With consistency search](#toc3_4_)
#   - [With custom callback](#toc3_5_)
#   - [With LangSmith tracing](#toc3_6_)
#   - [Simple check of list of vendors wether they are medical equipment vendors](#toc3_7_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=false
# 	anchor=true
# 	flat=false
# 	minLevel=1
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %% [markdown]
# Agentic approach to information checking

# %% [markdown]
# # <a id='toc2_'></a>[Imports](#toc0_)

# %%
import os
import sys

# Change working directory to parent (project root)
parent_dir = os.path.abspath(os.path.join(os.getcwd(), ".."))
os.chdir(parent_dir)

# Ensure parent directory is in sys.path so that pyagent_smith is importable
if parent_dir not in sys.path:
    sys.path.insert(0, parent_dir)

# %%
import warnings
from urllib3.exceptions import InsecureRequestWarning

warnings.filterwarnings("ignore", category=InsecureRequestWarning)

import pandas as pd
from IPython.display import display


from pyagent_smith.agent import build_chat_agent

import json
import re
from typing import List
import json5

# %%
# Set display options to show all rows
# pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
# pd.set_option("display.max_colwidth", None)
# pd.set_option("display.width", None)

# Optionally, reset display options after printing
# pd.reset_option('display.max_rows')
# pd.reset_option('display.max_columns')
# pd.reset_option('display.width')

# %% [markdown]
# # <a id='toc3_'></a>[Examples](#toc0_)

# %% [markdown]
# ## <a id='toc3_1_'></a>[Simple search](#toc0_)

# %%
def check_if_there_is_rock_climbing_around_cellecs():
    agent = build_chat_agent(
        system_prompt=(
            "You are a helpful assistant that researches locations and determines "
            "if there is any rock climbing available around them or not. "
            "Use web search to find accurate information about rock climbing locations."
        ),
        verbose=True,
    )

    if agent is None:
        return "Error: Ollama not configured"

    query = (
        "Is there any rock climbing around Cellecs, Catalunya?"
        "Search for information about rock climbing locations around Cellecs."
    )

    result = agent.invoke(query)

    print(f"Query: {query}")
    print(f"Result: {result}")

# %%
check_if_there_is_rock_climbing_around_cellecs()
# Out:
# [Tool] web_search started
# [Tool] Input: {'max_results': '5', 'query': 'rock climbing locations near Cellecs, Catalunya'}
# [Tool] Output: content="1. Catalunya – Rockfax\n   URL: https://rockfax.com/climbing-guides/rockfax-digital/catalunya/\n   In addition, are seven smaller crags situated near Barcelona and a couple more near Lleida.Barcelona Area Cellecs , Gelida, La Facu, La Font de l'Ametlló, Pas de la Mala Dona, Penya Ginesta, Subirats, Siurana. Lleida Area Ager, Cubells (free sample), Terradets, Vilanova de Meià.\n\n2. Cellecs | RockAroundTheWorld\n   URL: https://rockaroundtheworld.co.uk/2018/03/12/cellecs/\n   Plaça Cellecs is the best bit of rock ; a 20m high, easy angled, slab of crystalline granite with some knobbly holds and generally good friction.Tags: Barcelona, Catalunya , Cellecs , escalada., rock climbing . Post navigation.\n\n3. How to Do Rock Climbing ( Locations ) - Sims 4 - YouTube\n   URL: https://www.youtube.com/watch?v=cX2wysfh1BI\n   In this video, we will be showing you the locations to do the rock climbing in the Sims 4 game. #sims4 0:00 - Intro0:31 - Location 11:09 - Location 21:58 - L...\n\n4. fruit picking in France? near rock climbing locations ? - Tripadvisor\n   URL: https://www.tripadvisor.com/ShowTopic-g187070-i12-k6400354-Fruit_picking_in_France_near_rock_climbing_locations-France.html\n   I was going to go to Spain where I've picked and climbed in Catalunya before, but wanted to try somewhere new. If you have fruit picking advice but not rock climbing also, please respond anyway and I'll research nearby climbing after your recommendations.\n\n5. The 10 Best Rock Climbing Locations in... - YourAmazingPlaces.com\n   URL: https://www.youramazingplaces.com/the-10-best-rock-climbing-locations-in-europe/\n   The moderate rock climbing difficulty here includes unforgettable climbing along the Formentor peninsula sea cliffs and the overhands found at Es Fumat and La Creveta. Mallorca-Spain-620x413 The 10 Best Rock Climbing Locations in Europe.\n" name='web_search' tool_call_id='90f61120-4e25-4087-a2fc-547db4c2999b'
# [Tool] Output length: 1943 characters
# Query: Is there any rock climbing around Cellecs, Catalunya?Search for information about rock climbing locations around Cellecs.
# Result: Based on my research, it appears that there are several options for rock climbing near Cellecs, Catalunya. Here are some of the locations I found:
#
# * Plaça Cellecs is a popular spot for rock climbing in Barcelona, with a 20m high slab of crystalline granite.
# * Gelida, La Facu, La Font de l'Ametlló, Pas de la Mala Dona, Penya Ginesta, Subirats, and Siurana are all located near Barcelona and offer various levels of difficulty for climbers.
# * Ager, Cubells (free sample), Terradets, and Vilanova de Meià are located in the Lleida area and offer a range of climbing opportunities.
#
# Please note that this is not an exhaustive list and it's always best to check with local guides or climbing associations for up-to-date information on climbing locations and conditions.

# %% [markdown]
# ## <a id='toc3_2_'></a>[With conversation history](#toc0_)

# %%
def check_with_conversation_history():
    """Check with automatic conversation history for follow-up questions."""
    agent = build_chat_agent(
        system_prompt=(
            "You are a helpful assistant that researches locations and determines "
            "if there is any rock climbing available around them or not. "
            "Use web search to find accurate information about rock climbing locations."
        ),
        retain_chat_history=True,  # Enable automatic history retention
        verbose=True
    )

    if agent is None:
        return "Error: Ollama not configured"

    # First query - history is automatically maintained
    query1 = "Is there any rock climbing around Cellecs, Catalunya?"
    result1 = agent.invoke(query1)
    print(f"First query: {query1}")
    print(f"First response: {result1}")

    # Follow-up query - agent automatically uses previous conversation context
    query2 = "List all locations around."
    result2 = agent.invoke(query2)
    print(f"Follow-up query: {query2}")
    print(f"Follow-up response: {result2}")

    # print(f"agent.history: {agent.history}")
    return agent

# %%
agent = check_with_conversation_history()
# Out:
# [Tool] web_search started
# [Tool] Input: {'max_results': '10', 'query': 'rock climbing near Cellecs, Catalonia'}
# [Tool] Output: content="1. Rock Climbing near Barcelona - Laid-back places\n   URL: https://laidbackplaces.com/rock-climbing-near-barcelona/\n   September 20, 2022 - We climbed in Sector Placa (mostly slab, grades from 4 – 6b) and Sector Agulla de Cellecs (slab, a few short routes with roofs to practice aid climbing). Sant Llorenç de Munt is a popular hiking and climbing area and only a 30-40 minutes’ ...\n\n2. Laid-back places - Best rock climbing in Catalunya and other places\n   URL: https://laidbackplaces.com/\n   It is a very popular sport climbing destination. It is especially attractive during the hotter months thanks to its canyons with crystal clear water where you can enjoy a […] ... abandoned buildings adventure agriculture austria barcelona beach beaches boulder castle catalonia caves city cliff jumping cliffs climbing climbing wall costa brava costa dorada coves deep water soloing dws fun garden girona hiking idyllic laid-back laidback lleida mediterranean mountains mysterious places natural park nature park pyrenees rock climbing rocks sea summer swimming tarragona travel via ferrata waterfall\n\n3. Catalan
# [Tool] Output length: 3880 characters
# Follow-up query: List all locations around.
# Follow-up response: Here is the list of locations around Cellecs, Catalunya for rock climbing:
#
# 1. Sector Placa and Sector Agulla de Cellecs in the Sant Llorenç de Munt area
# 2. Montserrat
# 3. Garraf
# 4. Penedes
# 5. Rock Climbing near Barcelona - Laid-back places
# 6. Cellecs | RockAroundTheWorld
# 7. Climb Catalunya (organizes climbing trips to various locations)
# 8. Escalada Sector Transmutacio Cellecs in the Òrrius area
# 9. escalada Cellecs Map - Climbing site - Òrrius, Catalonia, Spain
# 10. UKC Logbook - Cellecs - UKClimbing (provides information on climbing routes and conditions)
# 11. Escalar en Cellecs (Orrius) - Zonas de Escalada (a guide to the area's climbing spots)
# 12. Escalada Aproximación Céllecs (Sector Placa) by RocJumper
# 13. Indoorwall Hospitalet Llobregat (an indoor climbing center)
#
# Please note that this is not an exhaustive list and there may be other locations available for rock climbing in the area. It's always a good idea to check with local climbing organizations or guides for up-to-date information on climbing conditions and access.

# %%
agent.chat_history
# Out:
# [HumanMessage(content='Is there any rock climbing around Cellecs, Catalunya?', additional_kwargs={}, response_metadata={}, id='2b5d7e3a-cfdc-498d-a63c-2768d6aff476'),
#  AIMessage(content="Yes, there are many rock climbing locations around Cellecs, Catalunya. Some popular options include:\n\n* Sector Placa and Sector Agulla de Cellecs in the Sant Llorenç de Munt area\n* The Catalan coastal ranges north, which offer a variety of sport climbing routes\n* Montserrat, a popular hiking and climbing destination with stunning views\n* Garraf and Penedes, both of which have a range of rock climbing routes\n\nThese locations offer a range of climbing styles and difficulties, from beginner-friendly slab routes to more challenging sport climbs. It's worth noting that some of these areas may require permission or guides to access.\n\nIt's also worth mentioning that Catalonia is known for its excellent rock climbing conditions, with mild winters and warm summers making it an ideal destination for climbers throughout the year.", additional_kwargs={}, response_metadata={}, id='196e8e24-30b6-4d1a-ae27-5c54a3c7baa0', tool_calls=[], invalid_tool_calls=[]),
#  HumanMessage(content='List all locations around.', additional_kwargs={}, response_metadata={}),
#  AIMessage(content="Here is the list of locations around Cellecs, Catalunya for rock climbing:\n\n1. Sector Placa and Sector Agulla de Cellecs in the Sant Llorenç de Munt area\n2. Montserrat\n3. Garraf\n4. Penedes\n5. Rock Climbing near Barcelona - Laid-back places\n6. Cellecs | RockAroundTheWorld\n7. Climb Catalunya (organizes climbing trips to various locations)\n8. Escalada Sector Transmutacio Cellecs in the Òrrius area\n9. escalada Cellecs Map - Climbing site - Òrrius, Catalonia, Spain\n10. UKC Logbook - Cellecs - UKClimbing (provides information on climbing routes and conditions)\n11. Escalar en Cellecs (Orrius) - Zonas de Escalada (a guide to the area's climbing spots)\n12. Escalada Aproximación Céllecs (Sector Placa) by RocJumper\n13. Indoorwall Hospitalet Llobregat (an indoor climbing center)\n\nPlease note that this is not an exhaustive list and there may be other locations available for rock climbing in the area. It's always a good idea to check with local climbing organizations or guides for up-to-date information on climbing conditions and access.", additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[])]

# %% [markdown]
# ## <a id='toc3_4_'></a>[With consistency search and custom callback](#toc0_)
#
# * i.e. multiple web search engines are used to find the most consistent answer https://www.promptingguide.ai/techniques/consistency

# %%
def check_with_self_consistency_search():
    """Use self-consistency search with majority voting for more reliable results."""
    agent = build_chat_agent(
        system_prompt=(
            "You are a helpful assistant that researches locations and determines "
            "if there is any rock climbing available around them or not. "
            "Use web search to find accurate information about rock climbing locations."
        ),
        use_self_consistency_search=True,  # Enable self-consistency with majority voting
        verbose=True,
    )

    if agent is None:
        return "Error: Ollama not configured"

    query = "Is Cellecs in Catalunya a climbing location?"
    result = agent.invoke(query)

    print(f"Query: {query}")
    print(f"Result: {result}")
    return result

# %%
result = check_with_self_consistency_search()
# Out:
# [Tool] web_search_with_self_consistency started
# [Tool] Input: {'max_results': '5', 'query': 'Callecs in Catalunya rock climbing'}
# [Tool] Output: content="1. Home - Climb Catalunya\n   URL: https://climbcatalunya.com/\n   Climb Catalunya organizes dedicated climbing trips to some of Europe's most dramatic rock climbing destinations. Relative novices and hardened enthusiasts alike can enjoy our hassle free holidays and long weekend climbing breaks. For those looking to improve their skills or climb their dream ...\n   (Consensus: 3/3 engines)\n\n2. Rock Climbing in Catalonia, Catalonia\n   URL: https://www.mountainproject.com/area/106002779/catalonia\n   Catalonia is one of the best places to climb in Spain. Plenty of sport crags known worldwide and lots of trad/adventure climbing areas. You can find different types of rock, but the most usual is limestone, with some really particular and nice conglomerate areas like the mystical Montserrat.\n   (Consensus: 3/3 engines)\n\n3. THE 15 BEST Catalonia Climbing Tours (with Prices) - Tripadvisor\n   URL: https://www.tripadvisor.com/Attractions-g187496-Activities-c61-t215-Catalonia.html\n   A professional climbing guide will… ... Not sure? You can cancel this reservation up to 24 hours in advance for a full refund. ... Via Ferrata is something everyone should try in their life. It is a great way to experience the thrill of the mountain in… ... Not sure? You can cancel this reservation up to 24 hours in advance for a full refund. ... We offer you a certified mountain guide and rock climbing instructor to enjoy a guided rock climbing trip in Montserrat, …\n   (Consensus: 3/3 engines)\n\n4. Laid-back places - Best rock climbing in Catalunya and other places\n   URL: https://laidbackplaces.com/\n   In the end, we had time to do a little more than that: DAY 1: Ferrata Roca Carrera K4 (Catalunya), duration about 1h, approach 30 minutes – GoogleMaps Ferrata […] La bañera rusa (lit. trans. The Russian Bath) is a small cove in a stunning natural environment, surrounded by cliffs with spectacular views. Next to it, a beautiful rock bridge over the deep clean waters which is a perfect spot for deep water solo. Perles with its superb rocks, tranquility and stunning setting is popular with local climbers but very little known beyond the borders of Catalunya.\n   (Consensus: 3/3 engines)\n\n5. Climbing in Barcelona and Catalonia: a Climbing Guide to Barcelona Areas\n   URL: https://www.movingtobarcelona.com/climbing-in-barcelona/\n   May 13, 2024 - Climbing in Garraf. For a hot day try Subirats, this is a more sheltered crag and will be in the shade by the afternoon. Subirats is situated in one of the biggest Cava producing areas of Cataluña and has grades ranging from 3 to 7a. Arbolí nearer to Siurana is also excellent on a sunny day as the foot of the crag, at least, is in the shade. Rockfax used to publish a mini-guide to climbing in Barcelona that you could buy online and download as a PDF.\n   (Consensus: 3/3 engines)\n" name='web_search_with_self_consistency' tool_call_id='ed6622bd-fe01-4a52-be9b-0e95843f0749'
# [Tool] Output length: 2954 characters
# Query: Is Cellecs in Catalunya a climbing location?
# Result: Based on my research, it appears that there are several rock climbing locations in Catalunya, including Callecs. Climb Catalunya is an organization that offers guided climbing trips to various destinations in the region, including Montserrat and other areas.
#
# Catalonia has a wide range of climbing options, from sport crags to traditional/adventure climbing areas, with different types of rock such as limestone and conglomerate.
#
# There are also several websites and guides available that provide information on rock climbing in Catalunya, including Mountain Project and Tripadvisor.
#
# Therefore, the answer to your question is yes, Callecs in Catalunya does appear to be a climbing location.

# %% [markdown]
# ## <a id='toc3_5_'></a>[Calculator tool with custom callback wo verbosity](#toc0_)

# %%
def check_with_custom_callbacks():
    """Example using custom callbacks for monitoring agent execution."""
    from langchain_core.callbacks import BaseCallbackHandler

    class SimpleCallbackHandler(BaseCallbackHandler):
        def on_tool_start(self, serialized, input_str, **kwargs):
            print(f"Tool started: {serialized.get('name', 'unknown')}")

        def on_tool_end(self, output, **kwargs):
            print(f"Tool completed. Output length: {len(str(output))}")

    agent = build_chat_agent(
        system_prompt="You are a helpful assistant.",
        callbacks=[SimpleCallbackHandler()],
    )

    if agent is None:
        return "Error: Ollama not configured"

    result = agent.invoke("What is 2+2? Use the calculator tool.")
    print(f"Query: What is 2+2? Use the calculator tool.")
    print(f"Result: {result}")

# %%
check_with_custom_callbacks()
# Out:
# Tool started: calculator
# Tool completed. Output length: 81
# Query: What is 2+2? Use the calculator tool.
# Result: The answer to your question is 4.

# %% [markdown]
# ## <a id='toc3_6_'></a>[Simple check of list of location wether there is any climbing around](#toc0_)

# %%
def parse_json_response(response_text: str) -> List[dict]:
    """Parse JSON response from agent."""
    json_match = re.search(r"```json\s*(.*?)\s*```", response_text, re.DOTALL)
    if json_match:
        response_text = json_match.group(1).strip()
    else:
        response_text = response_text.replace("```json", "").replace("```", "").strip()

    if response_text.strip().startswith("["):
        return json5.loads(response_text)
    elif response_text.strip().startswith("{"):
        return [json5.loads(response_text)]
    else:
        json_match = re.search(r"\[.*\]", response_text, re.DOTALL)
        if json_match:
            return json5.loads(json_match.group(0))
        raise ValueError("No valid JSON found")


def simple_climbing_locations_check(locations: List[str]) -> dict:
    """
    Simple example: Check if location is a climbing location using web search.

    Args:
        locations: List of location names

    Returns:
        dict with 'results' (list of responses) and 'all_received' (bool)
    """
    # Create agent with web search capability
    agent = build_chat_agent(
        system_prompt=(
            "You are a helpful assistant that researches locations and determines "
            "if there is any rock climbing available around them or not."
            "Use web search to find accurate information about rock climbing locations."
        ),
        retain_chat_history=True,
        verbose=True,
    )

    if agent is None:
        return {"error": "Agent not available", "results": [], "all_received": False}

    # Build prompt with explicit instruction to use web search
    schema = {
        "type": "object",
        "properties": {
            "location": {"type": "string"},
            "is_rock_climbing_location": {"type": "boolean"},
            "explanation": {"type": "string"},
            "web_search_results": {"type": "string"},
        },
        "required": ["location", "is_rock_climbing_location", "explanation", "web_search_results"],
    }

    location_list = "\n".join([f"  - {v}" for v in locations])
    prompt = (
        f"For each location in the list below, use the web_search tool to research whether "
        f"they are a rock climbing location or not.\n\n"
        f"CRITICAL: When using the web_search tool, you MUST pass a search query STRING as the 'query' parameter. "
        f"For example, for location 'Montserrat', call: web_search(query='rock climbing in Montserrat', max_results=5). "
        f"DO NOT pass JSON objects, schemas, or result fields to web_search - only pass search query strings like 'rock climbing in [location name]'.\n\n"
        f"Location list:\n{location_list}\n\n"
        f"Workflow:\n"
        f"1. For each location, call web_search with a query string like 'rock climbing in [location name]'\n"
        f"2. After getting search results for all locations, format your response as a JSON array\n"
        f"3. Each entry in the array should follow this format:\n"
        f"{json.dumps(schema, indent=2)}\n\n"
        f"Return only the JSON array, no other text."
    )

    # Call agent
    print(f"Prompt:\n {prompt}\n")
    response = agent.invoke(prompt)

    # Parse response
    try:
        results = parse_json_response(response)
        print(f"Results:\n {json.dumps(results, indent=2)}")
    except Exception as e:
        return {"error": str(e), "results": [], "all_received": False}

# %%
locations = ["Montserrat", "Siurana", "Margalef", "Garraf"]
simple_climbing_locations_check(locations)
# Out:
# Prompt:
#  For each location in the list below, use the web_search tool to research whether they are a rock climbing location or not.
#
# CRITICAL: When using the web_search tool, you MUST pass a search query STRING as the 'query' parameter. For example, for location 'Montserrat', call: web_search(query='rock climbing in Montserrat', max_results=5). DO NOT pass JSON objects, schemas, or result fields to web_search - only pass search query strings like 'rock climbing in [location name]'.
#
# Location list:
#   - Montserrat
#   - Siurana
#   - Margalef
#   - Garraf
#
# Workflow:
# 1. For each location, call web_search with a query string like 'rock climbing in [location name]'
# 2. After getting search results for all locations, format your response as a JSON array
# 3. Each entry in the array should follow this format:
# {
#   "type": "object",
#   "properties": {
#     "location": {
#       "type": "string"
#     },
#     "is_rock_climbing_location": {
#       "type": "boolean"
#     },
#     "explanation": {
#       "type": "string"
#     },
#     "web_search_results": {
#       "type": "string"
#     }
#   },
#   "required": [
#     "location",
#     "is_rock_climbing_location",
#     "explanation",
#     "web_search_results"
#   ]
# }
#
# Return only the JSON array, no other text.
#
# [Tool] web_search started[Tool] web_search started
# [Tool] Input: {'max_results': '5', 'query': 'Siurana rock climbing routes'}
#
# [Tool] Input: {'max_results': '5', 'query': 'rock climbing in Montserrat'}
# [Tool] web_search started
# [Tool] Input: {'max_results': '5', 'query': 'Margalef rock climbing locations'}
# [Tool] web_search started
# [Tool] Input: {'max_results': '5', 'query': 'Garraf rock climbing spots'}
# [Tool] Output: content='1. Siurana rock climbing , Spain\n   URL: https://www.planetmountain.com/en/news/climbing/siurana-rock-climbing-spain.html\n   Siurana rock climbing , Spain. Siurana in Spain: high in Catalonia close to Barcellona lies one of the most famous crags in the entire country, ideal as a winter climbing destination.\n\n2. Rock Climbing - Siurana . Trips, courses and tours\n   URL: https://www.explore-share.com/rock-climbing-trips/spain/siurana/\n   Siurana is one of the most elite rock climbing destinations in the world, with many professional rock climbers honing their skills and techniques here all-year-round. The conditions and climbs available are some of the best on earth, but there are also plenty of routes available for people of...\n\n3. What to see in Siurana (Tarragona), spectacular climbing landscape...\n   URL: https://guias-viajar.com/en/tourism-spain/visit-catalonia/tarragona-siurana-priorat/\n   Corner of Siurana in the Priorat of Tarragona. Another notable corner is the mountain retreat which since 1930 has been located on a rock .To get to Siurana you must deviate from the C-242 highway in Cornudella de Monsant, to head up the climb to the rocky enclave where it is located.\n\n4. Sierra de Prades Mountains rock climbing and sport climbing ...\n   URL: https://climb-europe.com/pages/rock-climbing-spain-sierra-de-prades-mountains\n   Siurana ’s position, along with its charm and high standard quality routes make this area one of the most popular winter rock climbing destinations in Europe, with great climbing conditions from autumn through to spring.\n\n5. Actor Network Theory analysis of roc climbing tourism in Siurana ...\n   URL: http://www.cek.ef.uni-lj.si/magister/wilson2749-B.pdf\n   4. It must be remembered that the equipping or rock climbs in Catalunya is a completely unregulated activity, and a route ’s inclusion in this guidebook is NOT a guarantee of the reliability of its in-situ gear. This shows the most common types of installed equipment in Siurana .\n' name='web_search' tool_call_id='d8e53c5a-5ecc-4dc7-8b48-0b2fdc445cef'
# [Tool] Output length: 2089 characters
# [Tool] Output: content="1. Rock Climbing in Montserrat | Guided Montserrat Climbing Trips\n   URL: https://www.explore-share.com/rock-climbing-trips/spain/montserrat/\n   Discover guided rock climbing in Montserrat near Barcelona. Multi-pitch routes, sport climbing and top local guides. Compare and book your climb online.\n\n2. Rock climbing - Montserrat | GdM\n   URL: https://gdm.cat/en/guided-activities/rock-climbing-montserrat\n   A Unique Playground for Climbers . Montserrat , a natural park and geological icon of Catalonia, offers over 6000 climbing routes and 1,500 distinctive conglomerate rock towers.\n\n3. Montserrat Rock Climbing and Sport Climbing , near Barcelona\n   URL: https://climb-europe.com/pages/rock-climbing-spain-montserrat\n   Montserrat - Vertiente Norte. This guidebook covers the rock climbing around the monastery and the campsite. Has everything from single pitch F8c's to mid-grade classic multi-pitch routes. This guidebook includes excellent topo's and lots of great photographs.\n\n4. Rock climbing in montserrat · 5.0\n   URL: https://www.airbnb.com/experiences/387758\n   Climb single routes in Montserrat , a unique geological formation with panoramic views.As if we were rock climbing with a friend. I would definitely do it again and be better prepared; shorter nails, thinner socks. The meet up was effortless, aside from the long commute from BCN by train.\n\n5. Guided Catalonia Climbing Trip in Montserrat | 57hours\n   URL: https://57hours.com/adventure/catalonia-climbing-trip/\n   Move beyond Montserrat and set your sights on Catalonia, which offers a variety of rock climbing destinations, such as Vilanova de Meià, Montrebei, Siurana, Margalef, Oliana, and La Mussara—all within a 2-hour drive from Montserrat .\n" name='web_search' tool_call_id='6e803330-6305-415f-ac7c-94cee2093dcf'
# [Tool] Output length: 1824 characters
# [Tool] Output: content="1. Rock Climbing in Garraf, Catalonia - Mountain Project\n   URL: https://www.mountainproject.com/area/116179007/garraf\n   Find rock climbing routes, photos, and guides for every state, along with experiences and advice from fellow climbers.\n\n2. Garraf, Sport climbing | theCrag\n   URL: https://www.thecrag.com/en/climbing/spain/barcelona-area/area/1706220834\n   Check out what is happening in Garraf . Get a detailed insight with a timeline showing Ticks by climbers like you Discussions of the community Updates to the index by our users and many more things. Login to see the timeline!\n\n3. The Best Rock Climbing Trails in Garraf, Catalonia (Spain)\n   URL: https://www.wikiloc.com/trails/rock-climbing/spain/catalonia/garraf\n   Find the best Rock Climbing trails in Garraf , Catalonia (Spain). Discover the most beautiful places, download GPS tracks and follow the top routes on a map. Record your own trail from the Wikiloc app, upload it and share it with the community.\n\n4. Climbing in Barcelona and Catalonia: a Climbing Guide to Barcelona Areas\n   URL: https://www.movingtobarcelona.com/climbing-in-barcelona/\n   Climbing in Barcelona. A little guide to rock climbing areas close to Barcelona, including Montserrat, Garraf and Penedes.\n\n5. Garraf - 27 Crags\n   URL: https://27crags.com/crags/garraf\n   Great crag if you have a couple of days for climbing while in Barcelona. Very polished rock after years of climbing plus wear and tear from the ocean. Go in the afternoon if it's a hot day, or you'll melt.\n" name='web_search' tool_call_id='c53385db-54c9-4107-91c7-a6e6fb092058'
# [Tool] Output length: 1614 characters
# [Tool] Output: content='1. Rock Climbing Margalef | ROCKBUSTERS\n   URL: https://rockbusters.net/location/margalef/\n   It is still superb, fun climbing in great scenery, where everybody can find what they need: more remote, tranquil crags, such as Catedral and Ermita, or always busy crags, filled with fanatics of hard sport climbing. Some of them are located just off the road: Raco de Finestra or El Laboratori .\n\n2. Rock climbing in Margalef, Spain\n   URL: https://margalefclimb.com/\n   All about Rock Climbing in Margalef, Spain. The ultimate climbing Guidebook. Info about Margalef village: how to come, where to stay, where to buy.\n\n3. Rock Climbing - Margalef. Trips, courses and tours\n   URL: https://www.explore-share.com/rock-climbing-trips/spain/margalef/\n   December 30, 2019 - Rock climbing week in Tarragona, Spain: Margalef, Siurana, Arboli & MontsantEnjoy a rock climbing holiday in Tarragona, Catalonia, climbing in the best spots of Margalef, Siurana, Arbolí and Montsant, along AEGM-certified mountain guide Santiago.\n\n4. Margalef Spain Climbing : A Remarkably Brilliant Guide [2021]\n   URL: https://www.thewanderingclimber.com/rock-climbing-margalef/\n   margalef street sign covered in rock climbing company stickers. Today I’m going to show you absolutely everything you need to know about Margalef Spain climbing . (No Joke). In fact, this is the exact same info I used during my two month climbing trip through Spain.\n\n5. Margalef sport climbing and rock climbing – Climb Europe\n   URL: https://climb-europe.com/pages/margalef-sport-climbing\n   Getting to Margalef. Margalef is located in the Sierra de Prades Mountains (also known as the Costa Daurada climbing area), close to the towns of Reus and Tarragona in southern Catalunya .\n' name='web_search' tool_call_id='559a328a-80ff-4aeb-858e-48c7b8a21b68'
# [Tool] Output length: 1832 characters
# Results:
#  [
#   {
#     "type": "object",
#     "properties": {
#       "location": "Montserrat",
#       "is_rock_climbing_location": true,
#       "explanation": "Montserrat offers over 6000 climbing routes and 1,500 distinctive conglomerate rock towers.",
#       "web_search_results": "https://www.explore-share.com/rock-climbing-trips/spain/montserrat/"
#     }
#   },
#   {
#     "type": "object",
#     "properties": {
#       "location": "Siurana",
#       "is_rock_climbing_location": true,
#       "explanation": "Siurana is one of the most elite rock climbing destinations in the world.",
#       "web_search_results": "https://www.planetmountain.com/en/news/climbing/siurana-rock-climbing-spain.html"
#     }
#   },
#   {
#     "type": "object",
#     "properties": {
#       "location": "Margalef",
#       "is_rock_climbing_location": true,
#       "explanation": "Margalef is a popular winter rock climbing destination in Europe.",
#       "web_search_results": "https://www.margalefclimb.com/"
#     }
#   },
#   {
#     "type": "object",
#     "properties": {
#       "location": "Garraf",
#       "is_rock_climbing_location": true,
#       "explanation": "Garraf is a popular rock climbing destination in Catalonia, Spain.",
#       "web_search_results": "https://www.mountainproject.com/area/116179007/garraf"
#     }
#   }
# ]
